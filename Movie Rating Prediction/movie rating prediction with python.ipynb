# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
movies=pd.read_csv("/content/movies.dat",sep="::",engine="python",encoding="ISO-8859-1")
users=pd.read_csv("/content/users.dat",sep="::",engine="python",encoding="ISO-8859-1")
ratings=pd.read_csv("/content/ratings.dat",sep="::",engine="python",encoding="ISO-8859-1")

# %%
# movies=movies.drop(columns=["1"])
movies.head(20)
# Out:
#      1                       Toy Story (1995)   Animation|Children's|Comedy
# 0    2                         Jumanji (1995)  Adventure|Children's|Fantasy
# 1    3                Grumpier Old Men (1995)                Comedy|Romance
# 2    4               Waiting to Exhale (1995)                  Comedy|Drama
# 3    5     Father of the Bride Part II (1995)                        Comedy
# 4    6                            Heat (1995)         Action|Crime|Thriller
# 5    7                         Sabrina (1995)                Comedy|Romance
# 6    8                    Tom and Huck (1995)          Adventure|Children's
# 7    9                    Sudden Death (1995)                        Action
# 8   10                       GoldenEye (1995)     Action|Adventure|Thriller
# 9   11         American President, The (1995)          Comedy|Drama|Romance
# 10  12     Dracula: Dead and Loving It (1995)                 Comedy|Horror
# 11  13                           Balto (1995)          Animation|Children's
# 12  14                           Nixon (1995)                         Drama
# 13  15                Cutthroat Island (1995)      Action|Adventure|Romance
# 14  16                          Casino (1995)                Drama|Thriller
# 15  17           Sense and Sensibility (1995)                 Drama|Romance
# 16  18                      Four Rooms (1995)                      Thriller
# 17  19  Ace Ventura: When Nature Calls (1995)                        Comedy
# 18  20                     Money Train (1995)                        Action
# 19  21                      Get Shorty (1995)           Action|Comedy|Drama

# %%
# ratings=ratings.drop(columns=["1"])
ratings.head(10)
# Out:
#    1  1193  5  978300760
# 0  1   661  3  978302109
# 1  1   914  3  978301968
# 2  1  3408  4  978300275
# 3  1  2355  5  978824291
# 4  1  1197  3  978302268
# 5  1  1287  5  978302039
# 6  1  2804  5  978300719
# 7  1   594  4  978302268
# 8  1   919  4  978301368
# 9  1   595  5  978824268

# %%
users.head(20)
# Out:
#      1  F  1.1  10  48067
# 0    2  M   56  16  70072
# 1    3  M   25  15  55117
# 2    4  M   45   7  02460
# 3    5  M   25  20  55455
# 4    6  F   50   9  55117
# 5    7  M   35   1  06810
# 6    8  M   25  12  11413
# 7    9  M   25  17  61614
# 8   10  F   35   1  95370
# 9   11  F   25   1  04093
# 10  12  M   25  12  32793
# 11  13  M   45   1  93304
# 12  14  M   35   0  60126
# 13  15  M   25   7  22903
# 14  16  F   35   0  20670
# 15  17  M   50   1  95350
# 16  18  F   18   3  95825
# 17  19  M    1  10  48073
# 18  20  M   25  14  55113
# 19  21  M   18  16  99353

# %%
movies.columns=["MovieIDs","Title_of_Movie","Genres"]

# %%
ratings.columns=["UserID","MovieID","Rating","Timestamp"]

# %%
users.columns=["UserID","Gender","Age","Occupation","Zip-code"]

# %%
movies
# Out:
#       MovieIDs                      Title_of_Movie  \
# 0            2                      Jumanji (1995)
# 1            3             Grumpier Old Men (1995)
# 2            4            Waiting to Exhale (1995)
# 3            5  Father of the Bride Part II (1995)
# 4            6                         Heat (1995)
# ...        ...                                 ...
# 3877      3948             Meet the Parents (2000)
# 3878      3949          Requiem for a Dream (2000)
# 3879      3950                    Tigerland (2000)
# 3880      3951             Two Family House (2000)
# 3881      3952               Contender, The (2000)
#
#                             Genres
# 0     Adventure|Children's|Fantasy
# 1                   Comedy|Romance
# 2                     Comedy|Drama
# 3                           Comedy
# 4            Action|Crime|Thriller
# ...                            ...
# 3877                        Comedy
# 3878                         Drama
# 3879                         Drama
# 3880                         Drama
# 3881                Drama|Thriller
#
# [3882 rows x 3 columns]

# %%
ratings
# Out:
#          UserID  MovieID  Rating  Timestamp
# 0             1      661       3  978302109
# 1             1      914       3  978301968
# 2             1     3408       4  978300275
# 3             1     2355       5  978824291
# 4             1     1197       3  978302268
# ...         ...      ...     ...        ...
# 1000203    6040     1091       1  956716541
# 1000204    6040     1094       5  956704887
# 1000205    6040      562       5  956704746
# 1000206    6040     1096       4  956715648
# 1000207    6040     1097       4  956715569
#
# [1000208 rows x 4 columns]

# %%
users
# Out:
#       UserID Gender  Age  Occupation Zip-code
# 0          2      M   56          16    70072
# 1          3      M   25          15    55117
# 2          4      M   45           7    02460
# 3          5      M   25          20    55455
# 4          6      F   50           9    55117
# ...      ...    ...  ...         ...      ...
# 6034    6036      F   25          15    32603
# 6035    6037      F   45           1    76006
# 6036    6038      F   56           1    14706
# 6037    6039      F   45           0    01060
# 6038    6040      M   25           6    11106
#
# [6039 rows x 5 columns]

# %%
movies.isna().sum()
# Out:
# MovieIDs          0
# Title_of_Movie    0
# Genres            0
# dtype: int64

# %%
users.isna().sum()
# Out:
# UserID        0
# Gender        0
# Age           0
# Occupation    0
# Zip-code      0
# dtype: int64

# %%
ratings.isna().sum()
# Out:
# UserID       0
# MovieID      0
# Rating       0
# Timestamp    0
# dtype: int64

# %%
sales_rating=pd.concat([movies,ratings,users],axis=1)
sales_rating.head(20)
# Out:
#     MovieIDs                         Title_of_Movie  \
# 0        2.0                         Jumanji (1995)
# 1        3.0                Grumpier Old Men (1995)
# 2        4.0               Waiting to Exhale (1995)
# 3        5.0     Father of the Bride Part II (1995)
# 4        6.0                            Heat (1995)
# 5        7.0                         Sabrina (1995)
# 6        8.0                    Tom and Huck (1995)
# 7        9.0                    Sudden Death (1995)
# 8       10.0                       GoldenEye (1995)
# 9       11.0         American President, The (1995)
# 10      12.0     Dracula: Dead and Loving It (1995)
# 11      13.0                           Balto (1995)
# 12      14.0                           Nixon (1995)
# 13      15.0                Cutthroat Island (1995)
# 14      16.0                          Casino (1995)
# 15      17.0           Sense and Sensibility (1995)
# 16      18.0                      Four Rooms (1995)
# 17      19.0  Ace Ventura: When Nature Calls (1995)
# 18      20.0                     Money Train (1995)
# 19      21.0                      Get Shorty (1995)
#
#                           Genres  UserID  MovieID  Rating  Timestamp  UserID  \
# 0   Adventure|Children's|Fantasy       1      661       3  978302109     2.0
# 1                 Comedy|Romance       1      914       3  978301968     3.0
# 2                   Comedy|Drama       1     3408       4  978300275     4.0
# 3                         Comedy       1     2355       5  978824291     5.0
# 4          Action|Crime|Thriller       1     1197       3  978302268     6.0
# 5                 Comedy|Romance       1     1287       5  978302039     7.0
# 6           Adventure|Children's       1     2804       5  978300719     8.0
# 7                         Action       1      594       4  978302268     9.0
# 8      Action|Adventure|Thriller       1      919       4  978301368    10.0
# 9           Comedy|Drama|Romance       1      595       5  978824268    11.0
# 10                 Comedy|Horror       1      938       4  978301752    12.0
# 11          Animation|Children's       1     2398       4  978302281    13.0
# 12                         Drama       1     2918       4  978302124    14.0
# 13      Action|Adventure|Romance       1     1035       5  978301753    15.0
# 14                Drama|Thriller       1     2791       4  978302188    16.0
# 15                 Drama|Romance       1     2687       3  978824268    17.0
# 16                      Thriller       1     2018       4  978301777    18.0
# 17                        Comedy       1     3105       5  978301713    19.0
# 18                        Action       1     2797       4  978302039    20.0
# 19           Action|Comedy|Drama       1     2321       3  978302205    21.0
#
#    Gender   Age  Occupation Zip-code
# 0       M  56.0        16.0    70072
# 1       M  25.0        15.0    55117
# 2       M  45.0         7.0    02460
# 3       M  25.0        20.0    55455
# 4       F  50.0         9.0    55117
# 5       M  35.0         1.0    06810
# 6       M  25.0        12.0    11413
# 7       M  25.0        17.0    61614
# 8       F  35.0         1.0    95370
# 9       F  25.0         1.0    04093
# 10      M  25.0        12.0    32793
# 11      M  45.0         1.0    93304
# 12      M  35.0         0.0    60126
# 13      M  25.0         7.0    22903
# 14      F  35.0         0.0    20670
# 15      M  50.0         1.0    95350
# 16      F  18.0         3.0    95825
# 17      M   1.0        10.0    48073
# 18      M  25.0        14.0    55113
# 19      M  18.0        16.0    99353

# %%
sales_rating.shape
# Out:
# (1000208, 12)

# %%
sales_rating.isna().sum()
# Out:
# MovieIDs          996326
# Title_of_Movie    996326
# Genres            996326
# UserID                 0
# MovieID                0
# Rating                 0
# Timestamp              0
# UserID            994169
# Gender            994169
# Age               994169
# Occupation        994169
# Zip-code          994169
# dtype: int64

# %%
sales_rating=sales_rating.dropna()

# %%
sales_rating.shape
# Out:
# (3882, 12)

# %%
sales_rating.isna().sum()
# Out:
# MovieIDs          0
# Title_of_Movie    0
# Genres            0
# UserID            0
# MovieID           0
# Rating            0
# Timestamp         0
# UserID            0
# Gender            0
# Age               0
# Occupation        0
# Zip-code          0
# dtype: int64

# %%
sales_rating["Age"].value_counts().plot(kind="bar")
plt.xlabel("age")
plt.ylabel("count of people")
plt.title("rate of age")
plt.show()

# %%
sales_rating=sales_rating.sort_values("Rating",ascending=False)

# %%
asd=sales_rating.groupby("MovieIDs")["Rating"].max().hist(bins=10)

# %%
sns.jointplot(x="Rating",y="MovieID",data=sales_rating,kind="reg")

# %%
sns.jointplot(x="Rating",y="MovieID",data=sales_rating,kind="kde")

# %%
sns.jointplot(x="MovieID",y="Age",data=sales_rating,kind="reg")

# %%
sns.heatmap(sales_rating.corr())
# Out:
# <ipython-input-65-28dfdac3c7e5>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(sales_rating.corr())
# <Axes: >

# %%
taining_Data=sales_rating[["MovieID","Age","Occupation"]]
testing_Data=sales_rating["Rating"]
x_train,x_test,y_train,y_test=train_test_split(taining_Data,testing_Data,test_size=0.2,random_state=42)

# %%
decision_tree=DecisionTreeClassifier()
decision_tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
decision_tree.score(x_train,y_train)
# Out:
# 0.9745571658615136

# %%
decision_tree.predict(x_test)
# Out:
# array([1, 4, 3, 3, 3, 2, 2, 5, 3, 1, 5, 4, 3, 3, 5, 4, 3, 5, 2, 1, 2, 4,
#        4, 3, 3, 4, 5, 3, 2, 4, 3, 5, 3, 4, 3, 1, 4, 5, 4, 5, 2, 3, 4, 3,
#        3, 3, 2, 3, 4, 5, 4, 3, 4, 2, 5, 3, 5, 3, 5, 4, 4, 4, 3, 2, 3, 3,
#        3, 5, 3, 4, 3, 5, 4, 4, 3, 3, 4, 3, 5, 3, 2, 2, 4, 4, 1, 3, 3, 4,
#        4, 3, 3, 3, 2, 1, 3, 5, 5, 5, 5, 4, 3, 4, 4, 3, 5, 4, 3, 5, 2, 5,
#        3, 3, 5, 5, 2, 3, 5, 1, 3, 4, 2, 4, 5, 5, 1, 2, 4, 1, 4, 4, 4, 4,
#        3, 3, 2, 5, 3, 4, 3, 5, 3, 3, 3, 4, 5, 3, 5, 4, 1, 3, 3, 4, 3, 5,
#        4, 3, 4, 5, 5, 5, 3, 2, 3, 5, 3, 5, 5, 3, 2, 4, 4, 3, 3, 5, 4, 3,
#        5, 3, 2, 3, 3, 3, 1, 2, 4, 1, 3, 4, 5, 4, 4, 5, 1, 4, 1, 5, 4, 3,
#        4, 4, 3, 3, 2, 4, 3, 3, 1, 2, 4, 4, 4, 4, 4, 2, 1, 5, 5, 4, 3, 4,
#        4, 5, 5, 4, 3, 4, 3, 4, 3, 4, 2, 5, 1, 5, 3, 1, 3, 5, 3, 1, 2, 5,
#        5, 3, 4, 2, 2, 4, 4, 4, 2, 5, 3, 4, 5, 4, 4, 5, 4, 1, 3, 4, 5, 3,
#        5, 3, 3, 5, 3, 1, 4, 4, 4, 3, 4, 5, 3, 4, 5, 5, 3, 1, 4, 5, 4, 2,
#        4, 4, 4, 4, 3, 4, 4, 4, 4, 4, 1, 4, 4, 2, 5, 2, 4, 4, 5, 2, 1, 4,
#        5, 4, 3, 2, 5, 3, 2, 5, 4, 4, 2, 3, 1, 3, 3, 4, 3, 4, 3, 5, 2, 4,
#        2, 1, 4, 4, 4, 4, 5, 5, 4, 5, 2, 5, 2, 3, 3, 2, 4, 3, 2, 4, 3, 4,
#        3, 3, 4, 3, 4, 4, 5, 3, 5, 3, 3, 3, 5, 3, 4, 3, 4, 3, 2, 3, 3, 3,
#        4, 2, 3, 4, 4, 3, 3, 1, 3, 2, 4, 3, 4, 2, 2, 4, 4, 5, 1, 5, 5, 3,
#        4, 5, 5, 5, 5, 3, 3, 3, 4, 5, 3, 5, 3, 3, 3, 1, 4, 4, 4, 4, 2, 3,
#        3, 4, 5, 3, 4, 4, 2, 5, 4, 3, 4, 5, 1, 5, 4, 4, 2, 4, 4, 2, 4, 4,
#        4, 5, 4, 3, 5, 3, 5, 5, 4, 4, 3, 3, 4, 2, 4, 3, 3, 3, 4, 2, 5, 3,
#        3, 3, 2, 4, 3, 4, 5, 5, 5, 4, 4, 3, 4, 5, 4, 2, 5, 3, 4, 5, 4, 4,
#        4, 4, 3, 1, 5, 4, 3, 4, 5, 3, 4, 4, 3, 1, 5, 4, 2, 2, 4, 4, 3, 3,
#        4, 2, 4, 3, 3, 5, 3, 3, 4, 3, 5, 4, 3, 4, 3, 3, 4, 3, 4, 5, 3, 3,
#        4, 5, 1, 4, 3, 3, 2, 4, 4, 3, 5, 4, 4, 4, 4, 3, 2, 4, 3, 4, 3, 2,
#        4, 4, 5, 3, 4, 2, 5, 5, 5, 3, 2, 2, 2, 5, 3, 4, 3, 3, 2, 2, 2, 5,
#        5, 5, 5, 4, 2, 1, 4, 5, 5, 4, 3, 1, 3, 3, 3, 5, 4, 5, 3, 2, 5, 4,
#        4, 3, 2, 1, 4, 2, 5, 2, 4, 5, 4, 4, 3, 3, 3, 2, 5, 5, 3, 4, 3, 4,
#        1, 3, 5, 4, 4, 3, 4, 5, 4, 1, 2, 4, 5, 3, 3, 3, 3, 2, 4, 4, 1, 2,
#        4, 5, 1, 3, 2, 4, 5, 4, 2, 3, 2, 2, 5, 4, 1, 2, 4, 2, 4, 5, 3, 3,
#        4, 5, 3, 3, 4, 2, 3, 4, 3, 3, 2, 4, 4, 5, 2, 2, 5, 4, 5, 4, 3, 5,
#        2, 4, 5, 4, 4, 4, 4, 3, 4, 5, 3, 4, 4, 3, 2, 2, 3, 4, 4, 5, 5, 4,
#        5, 4, 4, 5, 4, 3, 3, 3, 4, 4, 4, 2, 3, 4, 3, 5, 2, 4, 5, 3, 5, 5,
#        3, 4, 1, 4, 3, 4, 1, 3, 4, 4, 3, 2, 4, 4, 2, 2, 1, 4, 4, 4, 2, 3,
#        5, 3, 3, 5, 1, 3, 4, 3, 4, 5, 4, 3, 4, 2, 3, 4, 1, 4, 5, 3, 5, 1,
#        5, 5, 5, 1, 3, 5, 5])

# %%
print(y_test)
# Out:
# 407     2
# 1863    4
# 655     4
# 1264    2
# 3103    4
#        ..
# 3853    5
# 350     4
# 3571    2
# 3153    4
# 3006    5
# Name: Rating, Length: 777, dtype: int64
